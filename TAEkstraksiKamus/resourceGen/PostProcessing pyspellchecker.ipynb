# %%
import pandas as pd
import os
import re
from spellchecker import SpellChecker
import concurrent.futures

# %%
lookup_df = pd.read_csv('../Ekstraksi/12. Parallel Corpus - Spelling Checker/LookupIsFromIndonesia.csv')

spell = SpellChecker(language=None)
DICT_PATH = '../Code Tambahan/indonesian_dict.json' 

if os.path.exists(DICT_PATH):
    spell.word_frequency.load_dictionary(DICT_PATH)
    print(f"Loaded JSON dictionary successfully.")
else:
    raise FileNotFoundError(
        f"Custom dictionary not found at '{DICT_PATH}'. "
        "Check that the working directory is correct before running."
    )
# Out:
# Loaded JSON dictionary successfully.

# %%
def get_is_from_indonesia(input_path):
    filename = os.path.basename(input_path)
    try:
        file_id = filename.split('_')[0].strip()
    except IndexError:
        return False, -1

    for index, row in lookup_df.iterrows():
        raw_kamus = str(row['kamus'])
        match = re.search(r'\d+', raw_kamus)
        dict_id = match.group() if match else raw_kamus.strip()
            
        if dict_id == file_id:
            return True, int(row['is_from_indonesia'])
            
    return False, -1

# %%
def fix_sentence(sentence):
    def replace(match):
        word = match.group(0)
        lower_word = word.lower()
        
        if lower_word in spell.unknown([lower_word]):
            correction = spell.correction(lower_word)
            if correction and correction != lower_word:
                if word.istitle():
                    return correction.capitalize()
                elif word.isupper():
                    return correction.upper()
                else:
                    return correction
        return word

    return re.sub(r'[A-Za-z]+', replace, str(sentence))

# %%
def process_file(file_name):
    try:
        input_file  = os.path.join('../Ekstraksi/11. Parallel Corpus', file_name)
        output_file = os.path.join('../Ekstraksi/12. Parallel Corpus - Spelling Checker', file_name)

        success, is_from_indonesia = get_is_from_indonesia(input_file)
        if not success:
            return f"Skip: No matching ID for {file_name}"

        df = pd.read_csv(input_file)
        kalimat_asal_result_list   = []
        kalimat_tujuan_result_list = []

        for index, row in df.iterrows():
            orig_asal   = str(row['kalimat_asal'])
            orig_tujuan = str(row['kalimat_tujuan'])

            if is_from_indonesia:
                kalimat_asal_result_list.append(fix_sentence(orig_asal))
                kalimat_tujuan_result_list.append(orig_tujuan)
            else:
                kalimat_asal_result_list.append(orig_asal)
                kalimat_tujuan_result_list.append(fix_sentence(orig_tujuan))

        result_df = pd.DataFrame({
            'kalimat_asal':   kalimat_asal_result_list,
            'kalimat_tujuan': kalimat_tujuan_result_list
        })
        result_df.to_csv(output_file, index=False)
        return f"Processed: {file_name} ({len(result_df)} items)"

    except Exception as e:
        return f"Error in {file_name}: {str(e)}"

dir_path   = '../Ekstraksi/11. Parallel Corpus'
output_dir = '../Ekstraksi/12. Parallel Corpus - Spelling Checker/'
os.makedirs(output_dir, exist_ok=True)

files = [f for f in os.listdir(dir_path)
         if f.endswith('.csv') and f != 'LookupIsFromIndonesia.csv']

print(f"Starting to process {len(files)} files...")
futures = []
with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
    for f in files:
        futures.append(executor.submit(process_file, f))
    for count, future in enumerate(concurrent.futures.as_completed(futures), 1):
        print(f"[{count}/{len(files)}] {future.result()}")
# Out:
# Starting to process 60 files...
# [1/60] Processed: 10_Parcor.csv (2942 items)
# [2/60] Processed: 17_Parcor.csv (1673 items)
# [3/60] Processed: 18_Parcor.csv (2343 items)
# [4/60] Processed: 20_Parcor.csv (1719 items)
# [5/60] Processed: 16_Parcor.csv (2345 items)
# [6/60] Processed: 14_Parcor.csv (997 items)
# [7/60] Processed: 11_Parcor.csv (609 items)
# [8/60] Processed: 19_Parcor.csv (6236 items)
# [9/60] Processed: 23_Parcor.csv (2399 items)
# [10/60] Processed: 21_Parcor.csv (2019 items)
# [11/60] Processed: 26_Parcor.csv (668 items)
# [12/60] Processed: 12_Parcor.csv (4810 items)
# [13/60] Processed: 27_Parcor.csv (1738 items)
# [14/60] Processed: 29_Parcor.csv (1588 items)
# [15/60] Processed: 22_Parcor.csv (88 items)
# [16/60] Processed: 13_Parcor.csv (666 items)
# [17/60] Processed: 25_Parcor.csv (195 items)
# [18/60] Processed: 31_Parcor.csv (566 items)
# [19/60] Processed: 28_Parcor.csv (547 items)
# [20/60] Processed: 2_Parcor.csv (2047 items)
# [21/60] Processed: 32_Parcor.csv (1261 items)
# [22/60] Processed: 24_Parcor.csv (3518 items)
# [23/60] Processed: 33_Parcor.csv (1855 items)
# [24/60] Processed: 34_Parcor.csv (4407 items)
# [25/60] Processed: 41_Parcor.csv (4221 items)
# [26/60] Processed: 36_Parcor.csv (1258 items)
# [27/60] Processed: 44_Parcor.csv (687 items)
# [28/60] Processed: 38_Parcor.csv (1827 items)
# [29/60] Processed: 37_Parcor.csv (281 items)
# [30/60] Processed: 15_Parcor.csv (715 items)
# [31/60] Processed: 51_Parcor.csv (813 items)
# [32/60] Processed: 3_Parcor.csv (125 items)
# [33/60] Processed: 4_Parcor.csv (2973 items)
# [34/60] Processed: 48_Parcor.csv (193 items)
# [35/60] Processed: 42_Parcor.csv (4312 items)
# [36/60] Processed: 46_Parcor.csv (8484 items)
# [37/60] Processed: 52_Parcor.csv (2112 items)
# [38/60] Processed: 54_Parcor.csv (1174 items)
# [39/60] Processed: 5_Parcor.csv (790 items)
# [40/60] Processed: 58_Parcor.csv (1532 items)
# [41/60] Processed: 55_Parcor.csv (1829 items)
# [42/60] Processed: 50_Parcor.csv (679 items)
# [43/60] Processed: 70_Parcor.csv (48 items)
# [44/60] Processed: 71_Parcor.csv (727 items)
# [45/60] Processed: 66_Parcor.csv (1003 items)
# [46/60] Processed: 68_Parcor.csv (2044 items)
# [47/60] Processed: 84_Parcor.csv (264 items)
# [48/60] Processed: 56_Parcor.csv (2347 items)
# [49/60] Processed: 89_Parcor.csv (935 items)
# [50/60] Processed: 78_Parcor.csv (311 items)
# [51/60] Processed: 85_Parcor.csv (532 items)
# [52/60] Processed: 67_Parcor.csv (511 items)
# [53/60] Processed: 8_Parcor.csv (413 items)
# [54/60] Processed: 91_Parcor.csv (4762 items)
# [55/60] Processed: 9_Parcor.csv (1049 items)
# [56/60] Processed: 60_Parcor.csv (942 items)
# [57/60] Processed: 63_Parcor.csv (851 items)
# [58/60] Processed: 94_Parcor.csv (163 items)
# [59/60] Processed: 79_Parcor.csv (783 items)
# [60/60] Processed: 87_Parcor.csv (1009 items)
