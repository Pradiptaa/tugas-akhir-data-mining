# %% [markdown]
# # PostProcessing pyspellchecker — Billex & Morphology
#
# Companion to `PostProcessing pyspellchecker.ipynb`, which only handles the
# Parallel Corpus. This notebook applies the same `pyspellchecker` pipeline,
# with the same Indonesian dictionary, to the **other two NLP resources**:
#
# - **Bilingual Lexicon** (`9. Bilingual Lexicon - Fixed/*_Billex.csv`)
# - **Morphology** (`10. Morphology - Fixed/*_Morphology.csv`)
#
# ## Which column gets corrected?
#
# `LookupIsFromIndonesia.csv` says whether each dictionary is Indonesian→Regional
# (`is_from_indonesia=1`) or Regional→Indonesian (`is_from_indonesia=0`). Only
# the **Indonesian** side is run through the spellchecker; the regional side is
# left untouched because the Indonesian lexicon would falsely "correct" perfectly
# valid regional words.
#
# | Resource    | dir=1 (Ind→Reg) Indonesian column(s) | dir=0 (Reg→Ind) Indonesian column(s) |
# |-------------|--------------------------------------|--------------------------------------|
# | Billex      | `kata_asal`                          | `kata_tujuan`                        |
# | Morphology  | `kata` and `form`                    | *(skipped — see below)*              |
#
# **Why Morphology dir=0 is skipped.** When the source dictionary is
# Regional→Indonesian, the morphology pipeline stores the **regional** derived
# form in the `form` column and the **regional** headword in `kata` — the
# Indonesian glosses live in `makna` upstream and aren't carried into the
# Morphology resource. Running the spellchecker on regional words would corrupt
# them. These rows are passed through unchanged.
#
# ## Outputs
#
# - `../Ekstraksi/13. Bilingual Lexicon - Spelling Checker/<id>_Billex.csv`
# - `../Ekstraksi/13. Bilingual Lexicon - Spelling Checker/<id>_Billex_audit.csv`
# - `../Ekstraksi/14. Morphology - Spelling Checker/<id>_Morphology.csv`
# - `../Ekstraksi/14. Morphology - Spelling Checker/<id>_Morphology_audit.csv`
# - `_billex_summary.csv` / `_morph_summary.csv` — per-dict correction counts

# %% [markdown]
# ## 1. Imports & paths

# %%
import os
import re
import sys
from pathlib import Path
from typing import Optional

import pandas as pd
from spellchecker import SpellChecker
import concurrent.futures

# Reuse the same helpers used by the morphology / billex / parcor fix scripts
sys.path.insert(0, str(Path('.').resolve()))
from _common import (
    parse_dict_id,
    load_direction_lookup,
    direction_for,
    roles_for_billex,
    roles_for_morphology,
)

# Input directories — same as PostProcessing pyspellchecker.ipynb uses
BILLEX_SRC = Path('../Ekstraksi/9. Bilingual Lexicon - Fixed')
MORPH_SRC  = Path('../Ekstraksi/10. Morphology - Fixed')

# Output directories — sit alongside `12. Parallel Corpus - Spelling Checker`
BILLEX_DST = Path('../Ekstraksi/13. Bilingual Lexicon - Spelling Checker/dict_strategy_C')
MORPH_DST  = Path('../Ekstraksi/14. Morphology - Spelling Checker/dict_strategy_C')

BILLEX_DST.mkdir(parents=True, exist_ok=True)
MORPH_DST.mkdir(parents=True, exist_ok=True)

assert BILLEX_SRC.exists(), f'Billex source dir not found: {BILLEX_SRC.resolve()}'
assert MORPH_SRC.exists(),  f'Morph source dir not found:  {MORPH_SRC.resolve()}'

print(f'Reading Billex from: {BILLEX_SRC.resolve()}')
print(f'Reading Morph  from: {MORPH_SRC.resolve()}')
print(f'Writing Billex to:   {BILLEX_DST.resolve()}')
print(f'Writing Morph  to:   {MORPH_DST.resolve()}')
# Out:
# Reading Billex from: C:\Users\Legion\OneDrive\Documents\UNI\TA\tugas-akhir-data-mining\TAEkstraksiKamus\Ekstraksi\9. Bilingual Lexicon - Fixed
# Reading Morph  from: C:\Users\Legion\OneDrive\Documents\UNI\TA\tugas-akhir-data-mining\TAEkstraksiKamus\Ekstraksi\10. Morphology - Fixed
# Writing Billex to:   C:\Users\Legion\OneDrive\Documents\UNI\TA\tugas-akhir-data-mining\TAEkstraksiKamus\Ekstraksi\13. Bilingual Lexicon - Spelling Checker\dict_strategy_C
# Writing Morph  to:   C:\Users\Legion\OneDrive\Documents\UNI\TA\tugas-akhir-data-mining\TAEkstraksiKamus\Ekstraksi\14. Morphology - Spelling Checker\dict_strategy_C

# %% [markdown]
# ## 2. Load the Indonesian spellchecker dictionary
#
# Identical to the Parcor notebook — same dictionary, same `pyspellchecker`
# configuration. Swap `DICT_PATH` between the three strategies (A baseline,
# B all-tier-eligible, C ≥3-dict-frequency) the same way you would for Parcor.
#
# Loading the dictionary once at module level keeps the spellchecker stateless
# across threads.

# %%
lookup_df = pd.read_csv('../Ekstraksi/12. Parallel Corpus - Spelling Checker/LookupIsFromIndonesia.csv')

spell = SpellChecker(language=None)
# DICT_PATH = '../spellCheckDicts/vocab_strategies_v3_1/dict_strategy_original.json'
# DICT_PATH = '../spellCheckDicts/vocab_strategies_v3_1/dict_strategy_B.json'
DICT_PATH = '../spellCheckDicts/vocab_strategies_v3_1/dict_strategy_C.json'

if os.path.exists(DICT_PATH):
    spell.word_frequency.load_dictionary(DICT_PATH)
    print(f'Loaded JSON dictionary from {DICT_PATH}')
else:
    raise FileNotFoundError(
        f"Custom dictionary not found at '{DICT_PATH}'. "
        'Check that the working directory is correct before running.'
    )

# Direction lookup keyed by dict_id (reused for both resources)
DIRECTION = load_direction_lookup()
print(f'Loaded direction for {len(DIRECTION)} dictionaries')
# Out:
# Loaded JSON dictionary from ../spellCheckDicts/vocab_strategies_v3_1/dict_strategy_C.json
# Loaded direction for 68 dictionaries

# %% [markdown]
# ## 3. Core spellchecker helpers
#
# `fix_word` and `fix_sentence` are lifted directly from
# `PostProcessing pyspellchecker.ipynb` so the correction behaviour is
# **identical** to what was applied to Parcor — same case-preservation, same
# `spell.unknown` gate, same `spell.correction` call.
#
# `fix_word` is exposed separately because Billex/Morph cells are typically
# single tokens, not sentences. `fix_sentence` is kept for cells that contain
# multi-word headwords (Billex sometimes has these — e.g. `"abdi dalem"`).

# %%
def fix_word(word: str) -> str:
    """Correct a single token, preserving original case."""
    if not word or not word.isalpha():
        return word
    lower_word = word.lower()
    if lower_word in spell.unknown([lower_word]):
        correction = spell.correction(lower_word)
        if correction and correction != lower_word:
            if word.istitle():
                return correction.capitalize()
            elif word.isupper():
                return correction.upper()
            else:
                return correction
    return word


def fix_sentence(sentence) -> str:
    """Run the spellchecker over every alphabetic run in a string."""
    def replace(match):
        word = match.group(0)
        lower_word = word.lower()
        if lower_word in spell.unknown([lower_word]):
            correction = spell.correction(lower_word)
            if correction and correction != lower_word:
                if word.istitle():
                    return correction.capitalize()
                elif word.isupper():
                    return correction.upper()
                else:
                    return correction
        return word
    return re.sub(r'[A-Za-z]+', replace, str(sentence))


def fix_cell(value) -> str:
    """
    Spellcheck a Billex / Morphology cell. Single-word cells go through
    `fix_word` so we never insert spurious whitespace; multi-word cells fall
    back to `fix_sentence` so each token is treated independently.
    """
    if pd.isna(value):
        return value
    s = str(value)
    if not s.strip():
        return s
    # Single alphabetic token? use fix_word for cleanest case handling.
    if re.fullmatch(r"[A-Za-z]+", s.strip()):
        return fix_word(s.strip()) if s == s.strip() else s.replace(s.strip(), fix_word(s.strip()))
    return fix_sentence(s)

# %% [markdown]
# ## 4. Direction lookup wrapper
#
# Mirrors `get_is_from_indonesia` from the Parcor notebook so the file-name →
# direction resolution is consistent across all three resources. Returns
# `(success, is_from_indonesia)` to match the original signature.

# %%
def get_is_from_indonesia(input_path) -> tuple[bool, int]:
    filename = os.path.basename(str(input_path))
    file_id = parse_dict_id(filename)
    if file_id is None:
        return False, -1
    if file_id in DIRECTION:
        return True, DIRECTION[file_id]
    return False, -1


# Sanity check on a few known dicts
for fname in ['4_Billex.csv', '18_Morphology.csv', '24_Billex.csv']:
    print(f'  {fname:<22} -> {get_is_from_indonesia(fname)}')
# Out:
#   4_Billex.csv           -> (True, 1)
#   18_Morphology.csv      -> (True, 0)
#   24_Billex.csv          -> (True, 0)

# %% [markdown]
# ## 5. Billex processor
#
# For each `<id>_Billex.csv`:
#
# 1. Look up direction → know which column is Indonesian.
# 2. Spellcheck every cell in the Indonesian column.
# 3. Leave the regional column and `makna` untouched.
# 4. Write the pipeline-compatible CSV and a tracking audit CSV.
#
# The audit file keeps the original column under `<col>_original` and adds a
# boolean `<col>_corrected` flag so downstream evaluation can quantify how much
# the spellchecker actually changed.

# %%
def process_billex(file_name: str) -> str:
    try:
        input_file  = BILLEX_SRC / file_name
        output_file = BILLEX_DST / file_name
        audit_file  = BILLEX_DST / file_name.replace('.csv', '_audit.csv')

        # Skip audit files coming in from the upstream stage — we'll write our own.
        if file_name.endswith('_audit.csv'):
            return f'Skip: {file_name} (audit file from upstream)'

        success, is_from_indonesia = get_is_from_indonesia(input_file)
        if not success:
            return f'Skip: No matching ID for {file_name}'

        df = pd.read_csv(input_file)
        if 'kata_asal' not in df.columns or 'kata_tujuan' not in df.columns:
            return f'Skip: {file_name} missing kata_asal/kata_tujuan'

        ind_col, _ = roles_for_billex(is_from_indonesia)

        original = df[ind_col].astype(str).where(df[ind_col].notna(), '')
        corrected = original.apply(fix_cell)

        # Pipeline-compatible output: only the standard columns
        out_df = df.copy()
        out_df[ind_col] = corrected
        # Preserve same column order as input
        out_df.to_csv(output_file, index=False)

        # Audit CSV: original + corrected + flag
        audit_df = df.copy()
        audit_df[f'{ind_col}_original']  = original
        audit_df[ind_col]                = corrected
        audit_df[f'{ind_col}_corrected'] = original != corrected
        audit_df['direction']            = is_from_indonesia
        audit_df.to_csv(audit_file, index=False)

        n_changed = int((original != corrected).sum())
        return f'Processed: {file_name} ({len(out_df)} rows, {n_changed} corrections in {ind_col})'

    except Exception as e:
        return f'Error in {file_name}: {e}'


billex_files = [
    f for f in os.listdir(BILLEX_SRC)
    if f.endswith('.csv') and not f.endswith('_audit.csv')
    and not f.startswith('_')
]
print(f'Found {len(billex_files)} Billex files to process')

billex_results = []
with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
    futures = [executor.submit(process_billex, f) for f in billex_files]
    for count, future in enumerate(concurrent.futures.as_completed(futures), 1):
        msg = future.result()
        billex_results.append(msg)
        print(f'[{count}/{len(billex_files)}] {msg}')
# Out:
# Found 68 Billex files to process
# [1/68] Processed: 17_Billex.csv (7 rows, 0 corrections in kata_tujuan)
# [2/68] Processed: 11_Billex.csv (399 rows, 36 corrections in kata_tujuan)
# [3/68] Processed: 13_Billex.csv (254 rows, 57 corrections in kata_asal)
# [4/68] Processed: 1_Billex.csv (16 rows, 2 corrections in kata_tujuan)
# [5/68] Processed: 20_Billex.csv (0 rows, 0 corrections in kata_tujuan)
# [6/68] Processed: 15_Billex.csv (401 rows, 149 corrections in kata_asal)
# [7/68] Processed: 22_Billex.csv (5 rows, 0 corrections in kata_tujuan)
# [8/68] Processed: 14_Billex.csv (406 rows, 177 corrections in kata_asal)
# [9/68] Processed: 16_Billex.csv (1916 rows, 481 corrections in kata_asal)
# [10/68] Processed: 23_Billex.csv (1870 rows, 326 corrections in kata_tujuan)
# [11/68] Processed: 25_Billex.csv (168 rows, 39 corrections in kata_asal)
# [12/68] Processed: 10_Billex.csv (3800 rows, 1051 corrections in kata_asal)
# [13/68] Processed: 28_Billex.csv (658 rows, 67 corrections in kata_tujuan)
# [14/68] Processed: 29_Billex.csv (1 rows, 0 corrections in kata_tujuan)
# [15/68] Processed: 2_Billex.csv (76 rows, 12 corrections in kata_tujuan)
# [16/68] Processed: 31_Billex.csv (1 rows, 1 corrections in kata_tujuan)
# [17/68] Processed: 32_Billex.csv (5 rows, 0 corrections in kata_tujuan)
# [18/68] Processed: 33_Billex.csv (30 rows, 1 corrections in kata_tujuan)
# [19/68] Processed: 21_Billex.csv (1485 rows, 498 corrections in kata_asal)
# [20/68] Processed: 27_Billex.csv (1559 rows, 506 corrections in kata_asal)
# [21/68] Processed: 18_Billex.csv (9877 rows, 1429 corrections in kata_tujuan)
# [22/68] Processed: 37_Billex.csv (96 rows, 55 corrections in kata_asal)
# [23/68] Processed: 36_Billex.csv (1434 rows, 395 corrections in kata_asal)
# [24/68] Processed: 3_Billex.csv (19 rows, 1 corrections in kata_tujuan)
# [25/68] Processed: 38_Billex.csv (124 rows, 92 corrections in kata_asal)
# [26/68] Processed: 35_Billex.csv (2241 rows, 506 corrections in kata_asal)
# [27/68] Processed: 26_Billex.csv (3137 rows, 1172 corrections in kata_asal)
# [28/68] Processed: 24_Billex.csv (4405 rows, 1391 corrections in kata_tujuan)
# [29/68] Processed: 44_Billex.csv (3 rows, 1 corrections in kata_tujuan)
# [30/68] Processed: 19_Billex.csv (5380 rows, 1552 corrections in kata_asal)
# [31/68] Processed: 48_Billex.csv (1 rows, 0 corrections in kata_tujuan)
# [32/68] Processed: 4_Billex.csv (1894 rows, 374 corrections in kata_asal)
# [33/68] Processed: 50_Billex.csv (410 rows, 100 corrections in kata_asal)
# [34/68] Processed: 42_Billex.csv (3225 rows, 1029 corrections in kata_asal)
# [35/68] Processed: 52_Billex.csv (5 rows, 0 corrections in kata_tujuan)
# [36/68] Processed: 51_Billex.csv (294 rows, 14 corrections in kata_tujuan)
# [37/68] Processed: 45_Billex.csv (2377 rows, 703 corrections in kata_asal)
# [38/68] Processed: 56_Billex.csv (13 rows, 1 corrections in kata_tujuan)
# [39/68] Processed: 57_Billex.csv (9 rows, 1 corrections in kata_tujuan)
# [40/68] Processed: 58_Billex.csv (34 rows, 8 corrections in kata_tujuan)
# [41/68] Processed: 43_Billex.csv (3417 rows, 868 corrections in kata_asal)
# [42/68] Processed: 60_Billex.csv (105 rows, 8 corrections in kata_tujuan)
# [43/68] Processed: 61_Billex.csv (3 rows, 0 corrections in kata_tujuan)
# [44/68] Processed: 62_Billex.csv (92 rows, 7 corrections in kata_tujuan)
# [45/68] Processed: 63_Billex.csv (256 rows, 95 corrections in kata_asal)
# [46/68] Processed: 66_Billex.csv (2 rows, 2 corrections in kata_tujuan)
# [47/68] Processed: 54_Billex.csv (1085 rows, 267 corrections in kata_asal)
# [48/68] Processed: 12_Billex.csv (6192 rows, 3354 corrections in kata_asal)
# [49/68] Processed: 67_Billex.csv (162 rows, 13 corrections in kata_tujuan)
# [50/68] Processed: 70_Billex.csv (159 rows, 19 corrections in kata_tujuan)
# [51/68] Processed: 71_Billex.csv (783 rows, 21 corrections in kata_tujuan)
# [52/68] Processed: 78_Billex.csv (2 rows, 0 corrections in kata_tujuan)
# [53/68] Processed: 79_Billex.csv (754 rows, 104 corrections in kata_tujuan)
# [54/68] Processed: 84_Billex.csv (5 rows, 2 corrections in kata_tujuan)
# [55/68] Processed: 85_Billex.csv (26 rows, 3 corrections in kata_tujuan)
# [56/68] Processed: 77_Billex.csv (1284 rows, 93 corrections in kata_tujuan)
# [57/68] Processed: 89_Billex.csv (1128 rows, 34 corrections in kata_tujuan)
# [58/68] Processed: 34_Billex.csv (5730 rows, 2947 corrections in kata_asal)
# [59/68] Processed: 8_Billex.csv (342 rows, 114 corrections in kata_asal)
# [60/68] Processed: 94_Billex.csv (27 rows, 3 corrections in kata_tujuan)
# [61/68] Processed: 9_Billex.csv (23 rows, 0 corrections in kata_tujuan)
# [62/68] Processed: 46_Billex.csv (8618 rows, 1374 corrections in kata_tujuan)
# [63/68] Processed: 55_Billex.csv (1508 rows, 452 corrections in kata_asal)
# [64/68] Processed: 87_Billex.csv (761 rows, 332 corrections in kata_asal)
# [65/68] Processed: 68_Billex.csv (6936 rows, 577 corrections in kata_tujuan)
# [66/68] Processed: 5_Billex.csv (2395 rows, 746 corrections in kata_asal)
# [67/68] Processed: 91_Billex.csv (10077 rows, 1113 corrections in kata_tujuan)
# [68/68] Processed: 41_Billex.csv (7825 rows, 4029 corrections in kata_asal)

# %% [markdown]
# ## 6. Morphology processor
#
# For each `<id>_Morphology.csv`:
#
# - **dir=1 (Indonesian→Regional)**: both `kata` (headword) and `form` (derived
#   form) are Indonesian — spellcheck both.
# - **dir=0 (Regional→Indonesian)**: `kata` and `form` are in the regional
#   language — passthrough, do not corrupt with the Indonesian lexicon.
#
# The `tag` column is never touched (it's a POS tag, not natural-language
# content). The audit file follows the same convention as Billex: original
# copies are preserved and a `_corrected` flag is added per column.

# %%
def process_morph(file_name: str) -> str:
    try:
        input_file  = MORPH_SRC / file_name
        output_file = MORPH_DST / file_name
        audit_file  = MORPH_DST / file_name.replace('.csv', '_audit.csv')

        if file_name.endswith('_audit.csv'):
            return f'Skip: {file_name} (audit file from upstream)'

        success, is_from_indonesia = get_is_from_indonesia(input_file)
        if not success:
            return f'Skip: No matching ID for {file_name}'

        df = pd.read_csv(input_file)
        if 'kata' not in df.columns or 'form' not in df.columns:
            return f'Skip: {file_name} missing kata/form columns'

        # roles_for_morphology returns ('ind', 'reg') if dir==1 else ('reg', 'ind')
        # Here we only care WHETHER kata/form are Indonesian — they are iff dir==1.
        indonesian_columns = ['kata', 'form'] if is_from_indonesia == 1 else []

        out_df    = df.copy()
        audit_df  = df.copy()
        audit_df['direction'] = is_from_indonesia

        if not indonesian_columns:
            # Regional→Indonesian dict: passthrough.
            out_df.to_csv(output_file, index=False)
            audit_df['kata_corrected'] = False
            audit_df['form_corrected'] = False
            audit_df.to_csv(audit_file, index=False)
            return f'Passthrough (dir=0): {file_name} ({len(out_df)} rows)'

        n_changed_total = 0
        for col in indonesian_columns:
            original = df[col].astype(str).where(df[col].notna(), '')
            corrected = original.apply(fix_cell)
            out_df[col] = corrected
            audit_df[f'{col}_original']  = original
            audit_df[col]                = corrected
            audit_df[f'{col}_corrected'] = original != corrected
            n_changed_total += int((original != corrected).sum())

        out_df.to_csv(output_file, index=False)
        audit_df.to_csv(audit_file, index=False)
        return f'Processed: {file_name} ({len(out_df)} rows, {n_changed_total} corrections in {indonesian_columns})'

    except Exception as e:
        return f'Error in {file_name}: {e}'


morph_files = [
    f for f in os.listdir(MORPH_SRC)
    if f.endswith('.csv') and not f.endswith('_audit.csv')
    and not f.startswith('_')
]
print(f'Found {len(morph_files)} Morphology files to process')

morph_results = []
with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
    futures = [executor.submit(process_morph, f) for f in morph_files]
    for count, future in enumerate(concurrent.futures.as_completed(futures), 1):
        msg = future.result()
        morph_results.append(msg)
        print(f'[{count}/{len(morph_files)}] {msg}')
# Out:
# Found 130 Morphology files to process
# [1/130] Skip: 10_DerivedBillex.csv missing kata/form columns
# [2/130] Skip: 11_DerivedBillex.csv missing kata/form columns
# [3/130] Skip: 13_DerivedBillex.csv missing kata/form columns
# [4/130] Skip: 14_DerivedBillex.csv missing kata/form columns
# [5/130] Skip: 12_DerivedBillex.csv missing kata/form columns
# [6/130] Skip: 15_DerivedBillex.csv missing kata/form columns
# [7/130] Passthrough (dir=0): 11_Morphology.csv (205 rows)
# [8/130] Skip: 16_DerivedBillex.csv missing kata/form columns
# [9/130] Skip: 17_DerivedBillex.csv missing kata/form columns
# [10/130] Skip: 18_DerivedBillex.csv missing kata/form columns
# [11/130] Passthrough (dir=0): 17_Morphology.csv (4 rows)
# [12/130] Skip: 19_DerivedBillex.csv missing kata/form columns
# [13/130] Passthrough (dir=0): 18_Morphology.csv (2684 rows)
# [14/130] Skip: 1_DerivedBillex.csv missing kata/form columns
# [15/130] Passthrough (dir=0): 1_Morphology.csv (6 rows)
# [16/130] Passthrough (dir=0): 20_Morphology.csv (0 rows)
# [17/130] Skip: 21_DerivedBillex.csv missing kata/form columns
# [18/130] Processed: 14_Morphology.csv (93 rows, 67 corrections in ['kata', 'form'])
# [19/130] Passthrough (dir=0): 22_Morphology.csv (0 rows)
# [20/130] Skip: 23_DerivedBillex.csv missing kata/form columns
# [21/130] Passthrough (dir=0): 23_Morphology.csv (693 rows)
# [22/130] Skip: 24_DerivedBillex.csv missing kata/form columns
# [23/130] Passthrough (dir=0): 24_Morphology.csv (2172 rows)
# [24/130] Skip: 25_DerivedBillex.csv missing kata/form columns
# [25/130] Processed: 15_Morphology.csv (155 rows, 117 corrections in ['kata', 'form'])
# [26/130] Skip: 26_DerivedBillex.csv missing kata/form columns
# [27/130] Processed: 13_Morphology.csv (143 rows, 84 corrections in ['kata', 'form'])
# [28/130] Skip: 27_DerivedBillex.csv missing kata/form columns
# [29/130] Processed: 25_Morphology.csv (143 rows, 120 corrections in ['kata', 'form'])
# [30/130] Skip: 28_DerivedBillex.csv missing kata/form columns
# [31/130] Passthrough (dir=0): 28_Morphology.csv (183 rows)
# [32/130] Skip: 29_DerivedBillex.csv missing kata/form columns
# [33/130] Passthrough (dir=0): 29_Morphology.csv (2 rows)
# [34/130] Skip: 2_DerivedBillex.csv missing kata/form columns
# [35/130] Passthrough (dir=0): 2_Morphology.csv (12 rows)
# [36/130] Passthrough (dir=0): 31_Morphology.csv (0 rows)
# [37/130] Passthrough (dir=0): 32_Morphology.csv (0 rows)
# [38/130] Skip: 33_DerivedBillex.csv missing kata/form columns
# [39/130] Passthrough (dir=0): 33_Morphology.csv (27 rows)
# [40/130] Skip: 34_DerivedBillex.csv missing kata/form columns
# [41/130] Processed: 16_Morphology.csv (471 rows, 336 corrections in ['kata', 'form'])
# [42/130] Skip: 35_DerivedBillex.csv missing kata/form columns
# [43/130] Processed: 27_Morphology.csv (612 rows, 439 corrections in ['kata', 'form'])
# [44/130] Skip: 36_DerivedBillex.csv missing kata/form columns
# [45/130] Processed: 21_Morphology.csv (482 rows, 319 corrections in ['kata', 'form'])
# [46/130] Skip: 37_DerivedBillex.csv missing kata/form columns
# [47/130] Processed: 37_Morphology.csv (2 rows, 2 corrections in ['kata', 'form'])
# [48/130] Skip: 38_DerivedBillex.csv missing kata/form columns
# [49/130] Processed: 10_Morphology.csv (1125 rows, 568 corrections in ['kata', 'form'])
# [50/130] Skip: 3_DerivedBillex.csv missing kata/form columns
# [51/130] Passthrough (dir=0): 3_Morphology.csv (1 rows)
# [52/130] Skip: 41_DerivedBillex.csv missing kata/form columns
# [53/130] Processed: 38_Morphology.csv (73 rows, 90 corrections in ['kata', 'form'])
# [54/130] Skip: 42_DerivedBillex.csv missing kata/form columns
# [55/130] Processed: 36_Morphology.csv (626 rows, 368 corrections in ['kata', 'form'])
# [56/130] Skip: 43_DerivedBillex.csv missing kata/form columns
# [57/130] Processed: 26_Morphology.csv (1014 rows, 789 corrections in ['kata', 'form'])
# [58/130] Passthrough (dir=0): 44_Morphology.csv (0 rows)
# [59/130] Skip: 45_DerivedBillex.csv missing kata/form columns
# [60/130] Processed: 35_Morphology.csv (999 rows, 493 corrections in ['kata', 'form'])
# [61/130] Skip: 46_DerivedBillex.csv missing kata/form columns
# [62/130] Passthrough (dir=0): 46_Morphology.csv (4621 rows)
# [63/130] Passthrough (dir=0): 48_Morphology.csv (0 rows)
# [64/130] Skip: 4_DerivedBillex.csv missing kata/form columns
# [65/130] Processed: 42_Morphology.csv (1037 rows, 685 corrections in ['kata', 'form'])
# [66/130] Skip: 50_DerivedBillex.csv missing kata/form columns
# [67/130] Processed: 19_Morphology.csv (2032 rows, 1101 corrections in ['kata', 'form'])
# [68/130] Skip: 51_DerivedBillex.csv missing kata/form columns
# [69/130] Passthrough (dir=0): 51_Morphology.csv (39 rows)
# [70/130] Passthrough (dir=0): 52_Morphology.csv (0 rows)
# [71/130] Skip: 54_DerivedBillex.csv missing kata/form columns
# [72/130] Processed: 4_Morphology.csv (728 rows, 308 corrections in ['kata', 'form'])
# [73/130] Skip: 55_DerivedBillex.csv missing kata/form columns
# [74/130] Processed: 45_Morphology.csv (1039 rows, 631 corrections in ['kata', 'form'])
# [75/130] Skip: 56_DerivedBillex.csv missing kata/form columns
# [76/130] Passthrough (dir=0): 56_Morphology.csv (1 rows)
# [77/130] Skip: 57_DerivedBillex.csv missing kata/form columns
# [78/130] Passthrough (dir=0): 57_Morphology.csv (3 rows)
# [79/130] Skip: 58_DerivedBillex.csv missing kata/form columns
# [80/130] Passthrough (dir=0): 58_Morphology.csv (9 rows)
# [81/130] Skip: 5_DerivedBillex.csv missing kata/form columns
# [82/130] Processed: 43_Morphology.csv (1444 rows, 671 corrections in ['kata', 'form'])
# [83/130] Skip: 60_DerivedBillex.csv missing kata/form columns
# [84/130] Passthrough (dir=0): 60_Morphology.csv (7 rows)
# [85/130] Skip: 61_DerivedBillex.csv missing kata/form columns
# [86/130] Passthrough (dir=0): 61_Morphology.csv (2 rows)
# [87/130] Skip: 62_DerivedBillex.csv missing kata/form columns
# [88/130] Passthrough (dir=0): 62_Morphology.csv (63 rows)
# [89/130] Skip: 63_DerivedBillex.csv missing kata/form columns
# [90/130] Processed: 50_Morphology.csv (252 rows, 175 corrections in ['kata', 'form'])
# [91/130] Skip: 66_DerivedBillex.csv missing kata/form columns
# [92/130] Passthrough (dir=0): 66_Morphology.csv (6 rows)
# [93/130] Skip: 67_DerivedBillex.csv missing kata/form columns
# [94/130] Passthrough (dir=0): 67_Morphology.csv (65 rows)
# [95/130] Skip: 68_DerivedBillex.csv missing kata/form columns
# [96/130] Passthrough (dir=0): 68_Morphology.csv (2343 rows)
# [97/130] Skip: 70_DerivedBillex.csv missing kata/form columns
# [98/130] Passthrough (dir=0): 70_Morphology.csv (3 rows)
# [99/130] Skip: 71_DerivedBillex.csv missing kata/form columns
# [100/130] Passthrough (dir=0): 71_Morphology.csv (28 rows)
# [101/130] Skip: 77_DerivedBillex.csv missing kata/form columns
# [102/130] Passthrough (dir=0): 77_Morphology.csv (278 rows)
# [103/130] Passthrough (dir=0): 78_Morphology.csv (0 rows)
# [104/130] Skip: 79_DerivedBillex.csv missing kata/form columns
# [105/130] Passthrough (dir=0): 79_Morphology.csv (331 rows)
# [106/130] Skip: 84_DerivedBillex.csv missing kata/form columns
# [107/130] Passthrough (dir=0): 84_Morphology.csv (2 rows)
# [108/130] Skip: 85_DerivedBillex.csv missing kata/form columns
# [109/130] Passthrough (dir=0): 85_Morphology.csv (1 rows)
# [110/130] Skip: 87_DerivedBillex.csv missing kata/form columns
# [111/130] Processed: 63_Morphology.csv (53 rows, 36 corrections in ['kata', 'form'])
# [112/130] Skip: 89_DerivedBillex.csv missing kata/form columns
# [113/130] Passthrough (dir=0): 89_Morphology.csv (106 rows)
# [114/130] Skip: 8_DerivedBillex.csv missing kata/form columns
# [115/130] Processed: 8_Morphology.csv (124 rows, 125 corrections in ['kata', 'form'])
# [116/130] Skip: 91_DerivedBillex.csv missing kata/form columns
# [117/130] Passthrough (dir=0): 91_Morphology.csv (3668 rows)
# [118/130] Skip: 94_DerivedBillex.csv missing kata/form columns
# [119/130] Passthrough (dir=0): 94_Morphology.csv (5 rows)
# [120/130] Skip: 9_DerivedBillex.csv missing kata/form columns
# [121/130] Passthrough (dir=0): 9_Morphology.csv (8 rows)
# [122/130] Skip: No matching ID for ocr_pos_ambiguous.csv
# [123/130] Skip: No matching ID for ocr_pos_fixups.csv
# [124/130] Processed: 55_Morphology.csv (422 rows, 249 corrections in ['kata', 'form'])
# [125/130] Processed: 87_Morphology.csv (200 rows, 137 corrections in ['kata', 'form'])
# [126/130] Processed: 12_Morphology.csv (2645 rows, 2435 corrections in ['kata', 'form'])
# [127/130] Processed: 5_Morphology.csv (820 rows, 567 corrections in ['kata', 'form'])
# [128/130] Processed: 54_Morphology.csv (728 rows, 502 corrections in ['kata', 'form'])
# [129/130] Processed: 34_Morphology.csv (2322 rows, 2785 corrections in ['kata', 'form'])
# [130/130] Processed: 41_Morphology.csv (2883 rows, 3437 corrections in ['kata', 'form'])

# %% [markdown]
# ## 7. Per-dictionary correction summaries
#
# Re-reads the audit files to build a wide summary table. Useful for the thesis
# appendix to report, per dictionary, how many cells the spellchecker changed in
# each resource. Saves as `_billex_summary.csv` and `_morph_summary.csv` next to
# the output files.

# %%
def billex_summary_row(audit_path: Path) -> Optional[dict]:
    dict_id = parse_dict_id(audit_path.name)
    if dict_id is None:
        return None
    df = pd.read_csv(audit_path)
    if df.empty or 'direction' not in df.columns:
        return {
            'dict_id': dict_id,
            'direction': -1,
            'indonesian_column': '',
            'rows': len(df),
            'corrected_cells': 0,
        }
    direction = int(df['direction'].iloc[0])
    ind_col = 'kata_asal' if direction == 1 else 'kata_tujuan'
    flag = f'{ind_col}_corrected'
    return {
        'dict_id': dict_id,
        'direction': direction,
        'indonesian_column': ind_col,
        'rows': len(df),
        'corrected_cells': int(df[flag].sum()) if flag in df.columns else 0,
    }


def morph_summary_row(audit_path: Path) -> Optional[dict]:
    dict_id = parse_dict_id(audit_path.name)
    if dict_id is None:
        return None
    df = pd.read_csv(audit_path)
    if df.empty or 'direction' not in df.columns:
        return {
            'dict_id': dict_id,
            'direction': -1,
            'rows': len(df),
            'kata_corrected_cells': 0,
            'form_corrected_cells': 0,
            'total_corrected_cells': 0,
        }
    direction = int(df['direction'].iloc[0])
    kata_changed = int(df['kata_corrected'].sum()) if 'kata_corrected' in df.columns else 0
    form_changed = int(df['form_corrected'].sum()) if 'form_corrected' in df.columns else 0
    return {
        'dict_id': dict_id,
        'direction': direction,
        'rows': len(df),
        'kata_corrected_cells': kata_changed,
        'form_corrected_cells': form_changed,
        'total_corrected_cells': kata_changed + form_changed,
    }

# %% [markdown]
# ## 8. Cross-resource sanity checks
#
# Two consistency checks after the run:
#
# 1. Every Billex/Morph file in the source directory should now have a matching
#    output file (otherwise an error in §5–6 was silently swallowed).
# 2. The number of rows must be **exactly** preserved per file. The
#    spellchecker only edits cell values; it must not add or drop rows.

# %%
def check_row_parity(src_dir: Path, dst_dir: Path, suffix: str) -> pd.DataFrame:
    records = []
    for src in sorted(src_dir.glob(f'*_{suffix}.csv')):
        if src.name.endswith('_audit.csv'):
            continue
        dst = dst_dir / src.name
        if not dst.exists():
            records.append({'file': src.name, 'src_rows': -1, 'dst_rows': -1, 'status': 'MISSING'})
            continue
        try:
            n_src = len(pd.read_csv(src))
            n_dst = len(pd.read_csv(dst))
        except Exception as e:
            records.append({'file': src.name, 'src_rows': -1, 'dst_rows': -1, 'status': f'ERR: {e}'})
            continue
        status = 'OK' if n_src == n_dst else 'MISMATCH'
        records.append({'file': src.name, 'src_rows': n_src, 'dst_rows': n_dst, 'status': status})
    return pd.DataFrame(records)


billex_parity = check_row_parity(BILLEX_SRC, BILLEX_DST, 'Billex')
morph_parity  = check_row_parity(MORPH_SRC,  MORPH_DST,  'Morphology')

print('Billex parity:')
print(f"  OK:       {(billex_parity['status'] == 'OK').sum()}")
print(f"  MISSING:  {(billex_parity['status'] == 'MISSING').sum()}")
print(f"  MISMATCH: {(billex_parity['status'] == 'MISMATCH').sum()}")
bad = billex_parity[billex_parity['status'] != 'OK']
if not bad.empty:
    display(bad)

print('\nMorphology parity:')
print(f"  OK:       {(morph_parity['status'] == 'OK').sum()}")
print(f"  MISSING:  {(morph_parity['status'] == 'MISSING').sum()}")
print(f"  MISMATCH: {(morph_parity['status'] == 'MISMATCH').sum()}")
bad = morph_parity[morph_parity['status'] != 'OK']
if not bad.empty:
    display(bad)
# Out:
# Billex parity:
#   OK:       68
#   MISSING:  0
#   MISMATCH: 0
#
# Morphology parity:
#   OK:       68
#   MISSING:  0
#   MISMATCH: 0

# %% [markdown]
# ## 9. Spot-check a few corrections
#
# Prints sample original→corrected pairs from one Indonesian-source Billex
# (`dict 4`, Jambi) and one Indonesian-source Morphology (`dict 18`, Javanese).
# Sanity check that the corrections look reasonable before downstream stages
# consume the output.

# %%
def spot_check_billex(dict_id: str, n: int = 15) -> None:
    audit = BILLEX_DST / f'{dict_id}_Billex_audit.csv'
    if not audit.exists():
        print(f'  (no audit file for dict {dict_id})')
        return
    df = pd.read_csv(audit)
    direction = int(df['direction'].iloc[0]) if 'direction' in df.columns else 1
    ind_col = 'kata_asal' if direction == 1 else 'kata_tujuan'
    flag = f'{ind_col}_corrected'
    orig = f'{ind_col}_original'
    if flag not in df.columns:
        print(f'  (no correction flag in dict {dict_id})')
        return
    changed = df[df[flag]][[orig, ind_col]].drop_duplicates().head(n)
    print(f'  Dict {dict_id} Billex ({ind_col}, dir={direction}): {df[flag].sum()} cells changed')
    print(changed.to_string(index=False))


def spot_check_morph(dict_id: str, n: int = 15) -> None:
    audit = MORPH_DST / f'{dict_id}_Morphology_audit.csv'
    if not audit.exists():
        print(f'  (no audit file for dict {dict_id})')
        return
    df = pd.read_csv(audit)
    direction = int(df['direction'].iloc[0]) if 'direction' in df.columns else 1
    if direction != 1:
        print(f'  Dict {dict_id} Morphology: dir={direction}, passthrough (no Indonesian columns)')
        return
    changed_rows = df[df.get('kata_corrected', False) | df.get('form_corrected', False)]
    cols = ['kata_original', 'kata', 'form_original', 'form']
    cols = [c for c in cols if c in df.columns]
    print(f'  Dict {dict_id} Morphology (dir=1): '
          f"kata={df.get('kata_corrected', pd.Series(dtype=bool)).sum()} "
          f"form={df.get('form_corrected', pd.Series(dtype=bool)).sum()} corrections")
    print(changed_rows[cols].drop_duplicates().head(n).to_string(index=False))


print('=== Billex sample (dict 4) ===')
spot_check_billex('4')
print('\n=== Morphology sample (dict 18) ===')
spot_check_morph('18')
# Out:
# === Billex sample (dict 4) ===
#   Dict 4 Billex (kata_asal, dir=1): 374 cells changed
# kata_asal_original   kata_asal
#            absensi       absen
#              abses       absen
#               adon         don
#            aerobik     gerobak
#             afasia     rahasia
#              aksen       absen
#          keaktifan   kesaktian
#             aktris       keris
#             aktuai        akai
#             akurat       aurat
#           aimarhum    almarhum
#         pengamalan  pengadilan
#        pengambitan pengambilan
#             ambisi       ambil
#             amumsi        musi
#
# === Morphology sample (dict 18) ===
#   Dict 18 Morphology: dir=0, passthrough (no Indonesian columns)

# %% [markdown]
# ## 10. Notes
#
# - **Why a separate `13.` / `14.` directory?** Mirrors the convention used for
#   Parcor (`12. Parallel Corpus - Spelling Checker`) so each resource keeps
#   pre- and post-spellchecker copies side by side. Downstream notebooks can
#   switch between the two by changing one path.
#
# - **Switching dictionary strategy.** The same JSON dictionary toggle works
#   here — flip `DICT_PATH` to `indonesian_dict_strategy_B.json` or
#   `indonesian_dict_strategy_C.json` and rerun. Recommended to record which
#   strategy was used by saving the active path into `_billex_summary.csv` /
#   `_morph_summary.csv` as a column for the thesis appendix (left as a TODO).
#
# - **What this notebook deliberately does NOT do.**
#   - It does not re-run any of the upstream batch fixes (`Fix Billex Headword
#     Batch`, `Fix Morphology Batch`). Those must run first to produce the
#     `*_Fixed` directories this notebook reads from.
#   - It does not touch Parcor — see `PostProcessing pyspellchecker.ipynb`.
#   - It does not spellcheck regional-language content under any circumstances,
#     even when the Indonesian dictionary contains plausible-looking matches.
